# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
from inference import YOLOApplier
from os.path import join
import supervisely_lib as sly

# %matplotlib inline

# %%
# Full image inference config
# !cp /sly_task_data/task_settings_full.json /sly_task_data/task_settings.json

# Roi inference config
#!cp /sly_task_data/task_settings_roi.json /sly_task_data/task_settings.json

# Sliding window inference config
#!cp /sly_task_data/task_settings_slwindow.json /sly_task_data/task_settings.json

# %%
netw = YOLOApplier()
# Out:
# {"message": "Will init all required to inference.", "timestamp": "2018-10-08T15:25:18.164Z", "level": "info"}
# {"message": "Input config", "config": {"gpu_devices": [0], "model_classes": {"save_classes": "__all__", "add_suffix": "_yolo"}, "existing_objects": {"save_classes": [], "add_suffix": ""}, "mode": {"source": "full_image"}}, "timestamp": "2018-10-08T15:25:18.169Z", "level": "info"}
# {"message": "Full config", "config": {"gpu_devices": [0], "min_score_threshold": 0.5, "model_classes": {"save_classes": "__all__", "add_suffix": "_yolo"}, "existing_objects": {"save_classes": [], "add_suffix": ""}, "mode": {"source": "full_image"}}, "timestamp": "2018-10-08T15:25:18.173Z", "level": "info"}
# {"message": "Read model internal class mapping", "class_mapping": {"person": 0, "bicycle": 1, "car": 2, "motorbike": 3, "aeroplane": 4, "bus": 5, "train": 6, "truck": 7, "boat": 8, "traffic light": 9, "fire hydrant": 10, "stop sign": 11, "parking meter": 12, "bench": 13, "bird": 14, "cat": 15, "dog": 16, "horse": 17, "sheep": 18, "cow": 19, "elephant": 20, "bear": 21, "zebra": 22, "giraffe": 23, "backpack": 24, "umbrella": 25, "handbag": 26, "tie": 27, "suitcase": 28, "frisbee": 29, "skis": 30, "snowboard": 31, "sports ball": 32, "kite": 33, "baseball bat": 34, "baseball glove": 35, "skateboard": 36, "surfboard": 37, "tennis racket": 38, "bottle": 39, "wine glass": 40, "cup": 41, "fork": 42, "knife": 43, "spoon": 44, "bowl": 45, "banana": 46, "apple": 47, "sandwich": 48, "orange": 49, "broccoli": 50, "carrot": 51, "hot dog": 52, "pizza": 53, "donut": 54, "cake": 55, "chair": 56, "sofa": 57, "pottedplant": 58, "bed": 59, "diningtable": 60, "toilet": 61, "tvmonitor": 62, "laptop": 63, "mouse": 64, "remote": 65, "keyboard": 66, "cell phone": 67, "microwave": 68, "oven": 69, "toaster": 70, "sink": 71, "refrigerator": 72, "book": 73, "clock": 74, "vase": 75, "scissors": 76, "teddy bear": 77, "hair drier": 78, "toothbrush": 79}, "timestamp": "2018-10-08T15:25:18.180Z", "level": "info"}
# {"message": "Read model out classes", "classes": [{"title": "person", "shape": "rectangle", "color": "#92d086"}, {"title": "bicycle", "shape": "rectangle", "color": "#747fe9"}, {"title": "car", "shape": "rectangle", "color": "#e9bdcf"}, {"title": "motorbike", "shape": "rectangle", "color": "#6fbef5"}, {"title": "aeroplane", "shape": "rectangle", "color": "#5c7e68"}, {"title": "bus", "shape": "rectangle", "color": "#d4ef86"}, {"title": "train", "shape": "rectangle", "color": "#8cb4b7"}, {"title": "truck", "shape": "rectangle", "color": "#e7deb4"}, {"title": "boat", "shape": "rectangle", "color": "#d556d3"}, {"title": "traffic light", "shape": "rectangle", "color": "#89ce68"}, {"title": "fire hydrant", "shape": "rectangle", "color": "#c2a0b7"}, {"title": "stop sign", "shape": "rectangle", "color": "#839cbf"}, {"title": "parking meter", "shape": "rectangle", "color": "#60a360"}, {"title": "bench", "shape": "rectangle", "color": "#e8cae1"}, {"title": "bird", "shape": "rectangle", "color": "#fdc0b9"}, {"title": "cat", "shape": "rectangle", "color": "#6dfaa7"}, {"title": "dog", "shape": "rectangle", "color": "#d6e3df"}, {"title": "horse", "shape": "rectangle", "color": "#d7a487"}, {"title": "sheep", "shape": "rectangle", "color": "#d070b5"}, {"title": "cow", "shape": "rectangle", "color": "#64d389"}, {"title": "elephant", "shape": "rectangle", "color": "#b2bda6"}, {"title": "bear", "shape": "rectangle", "color": "#758181"}, {"title": "zebra", "shape": "rectangle", "color": "#a0cf96"}, {"title": "giraffe", "shape": "rectangle", "color": "#5b9bba"}, {"title": "backpack", "shape": "rectangle", "color": "#e4d99d"}, {"title": "umbrella", "shape": "rectangle", "color": "#88a9e5"}, {"title": "handbag", "shape": "rectangle", "color": "#64b5fb"}, {"title": "tie", "shape": "rectangle", "color": "#5fc9e5"}, {"title": "suitcase", "shape": "rectangle", "color": "#b6e3c8"}, {"title": "frisbee", "shape": "rectangle", "color": "#66a85e"}, {"title": "skis", "shape": "rectangle", "color": "#74a657"}, {"title": "snowboard", "shape": "rectangle", "color": "#e798a0"}, {"title": "sports ball", "shape": "rectangle", "color": "#fdeff6"}, {"title": "kite", "shape": "rectangle", "color": "#6b9ed3"}, {"title": "baseball bat", "shape": "rectangle", "color": "#7b64e9"}, {"title": "baseball glove", "shape": "rectangle", "color": "#e17eb8"}, {"title": "skateboard", "shape": "rectangle", "color": "#d8abae"}, {"title": "surfboard", "shape": "rectangle", "color": "#90d8bc"}, {"title": "tennis racket", "shape": "rectangle", "color": "#b69cfa"}, {"title": "bottle", "shape": "rectangle", "color": "#e6d19f"}, {"title": "wine glass", "shape": "rectangle", "color": "#b7fe62"}, {"title": "cup", "shape": "rectangle", "color": "#d7f378"}, {"title": "fork", "shape": "rectangle", "color": "#94f77e"}, {"title": "knife", "shape": "rectangle", "color": "#af64b7"}, {"title": "spoon", "shape": "rectangle", "color": "#f5abc6"}, {"title": "bowl", "shape": "rectangle", "color": "#60d864"}, {"title": "banana", "shape": "rectangle", "color": "#7b8768"}, {"title": "apple", "shape": "rectangle", "color": "#d19398"}, {"title": "sandwich", "shape": "rectangle", "color": "#d3d183"}, {"title": "orange", "shape": "rectangle", "color": "#7384e2"}, {"title": "broccoli", "shape": "rectangle", "color": "#6cea71"}, {"title": "carrot", "shape": "rectangle", "color": "#8879ee"}, {"title": "hot dog", "shape": "rectangle", "color": "#6557e6"}, {"title": "pizza", "shape": "rectangle", "color": "#80e9f0"}, {"title": "donut", "shape": "rectangle", "color": "#d9febb"}, {"title": "cake", "shape": "rectangle", "color": "#76c6a0"}, {"title": "chair", "shape": "rectangle", "color": "#d56078"}, {"title": "sofa", "shape": "rectangle", "color": "#f091b1"}, {"title": "pottedplant", "shape": "rectangle", "color": "#eed3f1"}, {"title": "bed", "shape": "rectangle", "color": "#bac69d"}, {"title": "diningtable", "shape": "rectangle", "color": "#c8db7f"}, {"title": "toilet", "shape": "rectangle", "color": "#aff768"}, {" ...
# {"message": "Weights are loaded.", "timestamp": "2018-10-08T15:25:22.599Z", "level": "info"}
# {"message": "Project structure has been read. Samples: 1.", "timestamp": "2018-10-08T15:25:22.600Z", "level": "info"}
# {"message": "Model is ready to inference.", "timestamp": "2018-10-08T15:25:22.601Z", "level": "info"}

# %%
model = sly.InferenceFeederFactory.create(netw.config, netw.helper.in_project_meta, netw.train_classes)

# %%
project_meta = netw.helper.in_project_meta  # Project meta contains list of project classes.
project_dir = netw.helper.paths.project_dir
project_fs = sly.ProjectFS.from_disk_dir_project(project_dir)

# %%
for item_descr in project_fs:
    plt.figure(figsize=(50, 50))
    ann_packed = sly.json_load(item_descr.ann_path)
    ann = sly.Annotation.from_packed(ann_packed, project_meta)
    img = cv2.imread(item_descr.img_path)[:, :, ::-1].astype(np.uint8)
    new_ann = model.feed(img, ann, netw._infer_on_img)
    for obj in new_ann["objects"]:
        if "person" in obj.class_title:
            obj.draw_contour(img, [0,255,0], 2)
    plt.subplot(3,1,1)
    plt.imshow(img)
    plt.show()
